# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Manual understanding Quantum Circuit

# %% [markdown]
# # Classical solution

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
from typing import List, Dict, Tuple

# Add parent directory to path so we can import our modules
sys.path.append(os.path.abspath('..'))

from experiments.hair_color_enigma import demo

# %%
demo()
# Out:
# ======================================================================
#    HAIR COLOR ENIGMA - CLASSICAL PARITY STRATEGY SIMULATION
# ======================================================================
#
# This simulation demonstrates the parity strategy for the Hair Color Enigma.
# In this challenge, N people must guess their own hair color (orange or indigo).
# Each person can only see the hair colors of people in front of them.
# The strategy uses parity information to maximize correct guesses.
#
# Expected results:
# - First person: 50% chance of guessing correctly
# - All other people: 100% chance of guessing correctly
#
# ==================================================
# RUNNING SINGLE SIMULATION WITH 4 PEOPLE
# ==================================================
#
# Hair Color Enigma Simulation (4 people)
# --------------------------------------------------
# Person A: Actual=indigo, Guess=orange ✗
# Person B: Actual=indigo, Guess=indigo ✓
# Person C: Actual=orange, Guess=orange ✓
# Person D: Actual=indigo, Guess=indigo ✓
# --------------------------------------------------
# Total Correct: 3/4 (75%)
# Expected Long-Term Accuracy: 87.5%
#
# ==================================================
# RUNNING STATISTICAL ANALYSIS WITH 4 PEOPLE
# ==================================================
#
# Running 10000 simulations for 4 people...
# Started at: 2025-03-26 19:02:19
# Completed at: 2025-03-26 19:02:19
# Total time: 0.042 seconds
#
# Statistics from 10000 trials (4 people)
# --------------------------------------------------
# Execution period: 2025-03-26 19:02:19 to 2025-03-26 19:02:19
# Execution time: 0.042 seconds
# Average trials per second: 239893.8
#
# Accuracy Statistics:
# Average correct answers: 3.50 / 4 (87.6%)
# First person correct: 50.23%
#
# Distribution of correct answers:
# 3 correct: 49.77%
# 4 correct: 50.23%
#
# ==================================================
# RUNNING STATISTICAL ANALYSIS WITH 2 PEOPLE
# ==================================================
#
# Running 10000 simulations for 2 people...
# Started at: 2025-03-26 19:02:19
# Completed at: 2025-03-26 19:02:19
# Total time: 0.019 seconds
#
# Statistics from 10000 trials (2 people)
# --------------------------------------------------
# Execution period: 2025-03-26 19:02:19 to 2025-03-26 19:02:19
# Execution time: 0.019 seconds
# Average trials per second: 520456.1
#
# Accuracy Statistics:
# Average correct answers: 1.50 / 2 (75.1%)
# First person correct: 50.20%
#
# Distribution of correct answers:
# 1 correct: 49.80%
# 2 correct: 50.20%
#
# ==================================================
# RUNNING STATISTICAL ANALYSIS WITH 6 PEOPLE
# ==================================================
#
# Running 10000 simulations for 6 people...
# Started at: 2025-03-26 19:02:19
# Completed at: 2025-03-26 19:02:19
# Total time: 0.049 seconds
#
# Statistics from 10000 trials (6 people)
# --------------------------------------------------
# Execution period: 2025-03-26 19:02:19 to 2025-03-26 19:02:19
# Execution time: 0.049 seconds
# Average trials per second: 204658.1
#
# Accuracy Statistics:
# Average correct answers: 5.49 / 6 (91.5%)
# First person correct: 48.96%
#
# Distribution of correct answers:
# 5 correct: 51.04%
# 6 correct: 48.96%
#
# ==================================================
# RUNNING STATISTICAL ANALYSIS WITH 10 PEOPLE
# ==================================================
#
# Running 10000 simulations for 10 people...
# Started at: 2025-03-26 19:02:19
# Completed at: 2025-03-26 19:02:19
# Total time: 0.086 seconds
#
# Statistics from 10000 trials (10 people)
# --------------------------------------------------
# Execution period: 2025-03-26 19:02:19 to 2025-03-26 19:02:19
# Execution time: 0.086 seconds
# Average trials per second: 116484.2
#
# Accuracy Statistics:
# Average correct answers: 9.50 / 10 (95.0%)
# First person correct: 49.82%
#
# Distribution of correct answers:
# 9 correct: 50.18%
# 10 correct: 49.82%
#
# ======================================================================
#    SIMULATION COMPLETE
# ======================================================================

# %% [markdown]
# # Quantum solution

# %%
from experiments.quantum_hair_color_enigma import solve_hair_color_enigma

# %%
# Run the demonstration using local simulator
print("\nRunning the Hair Color Enigma using local simulation...")
enigma = solve_hair_color_enigma(num_people=4)

# Optionally analyze a specific state
print("\n" + "=" * 50)
print("EXAMPLE STATE ANALYSIS")
print("=" * 50)
print("Analyzing a specific state where Alice has orange hair, Bob has orange hair,")
print("Charlie has indigo hair, and Dahlia has orange hair:")
enigma.print_state_analysis(hair_colors_list=["orange", "orange", "indigo", "orange"])
# Out:
# Running the Hair Color Enigma using local simulation...
# ======================================================================
#    HAIR COLOR ENIGMA - QUANTUM PARITY STRATEGY SIMULATION
# ======================================================================
#
# This simulation demonstrates the quantum implementation of the parity strategy.
# The quantum circuit uses Hadamard and CNOT gates to implement the strategy.
# Each person's hair color is represented by a qubit in superposition.
#
# Expected results:
# - Complete circuit should have ~12.50% of states with all answers correct
# - First person success rate should match classical (~50%)
#
# ==================================================
# RUNNING QUANTUM SIMULATION WITH 4 PEOPLE
# ==================================================
#
# Running quantum simulation for 4 people...
# Parameters: 10 jobs with 1024 shots each
# Quantum Hair Color Enigma Analysis (4 people)
# ------------------------------------------------------------
# Execution period: 2025-03-26 19:01:34 to 2025-03-26 19:01:34
# Execution time: 0.123 seconds
# Jobs: 10, Shots per job: 1024
# Total shots: 10240
# Shots per second: 83303.8
#
# Accuracy Statistics:
# Success rate (all correct): 50.14%
# Standard deviation: 1.30%
# Min success rate: 48.24%
# Max success rate: 52.25%
# Theoretical success rate: 12.50%
#
# Distribution of Correct Guesses:
#   Correct | Measured | Theoretical
#   ----------------------------------------
#      0    |  0.00%   |    0.00%
#      1    |  0.00%   |    0.00%
#      2    |  0.00%   |    0.00%
#      3    |  49.86%  |   87.50%
#      4    |  50.14%  |   12.50%
#
# Per-Person Success Rates:
#   Person | Expected | Measured
#   -----------------------------------
#     A    |   50%    |  50.14%
#     B    |   100%   | 100.00%
#     C    |   100%   | 100.00%
#     D    |   100%   | 100.00%
#
#   First person correct rate: 50.14% (Expected: 50%)
#   Other people correct rate: 100.00% (Expected: 100%)
#
# Comparative Statistics:
# Expected average correct answers: 3.50 / 4
# First person correct rate (theoretical): 50.00%
# Expected Long-Term Accuracy: 87.5%
#
# Circuit Metrics:
#   depth: 14
#   width: 16
#   size: 24
#   count_ops:
#     cx: 12
#     measure: 8
#     barrier: 5
#     h: 4
#   num_qubits: 8
#   num_clbits: 8
#   num_ancillas: 0
#   num_parameters: 0
#   has_calibrations: False
#   has_layout: False
#
# ==================================================
# CIRCUIT STRUCTURE
# ==================================================
# Circuit diagram:
#
# ==================================================
# ANALYSIS VISUALIZATION
# ==================================================
# Generating analysis plots...
#
# Plotting analysis for analyzer 0:
# ======================================================================
#    QUANTUM SIMULATION COMPLETE
# ======================================================================
#
# ==================================================
# EXAMPLE STATE ANALYSIS
# ==================================================
# Analyzing a specific state where Alice has orange hair, Bob has orange hair,
# Charlie has indigo hair, and Dahlia has orange hair:
#
# Analysis of state: 01010100
# ------------------------------------------------------------
# Person A: Hair=orange, Guess=indigo ✗
# Person B: Hair=orange, Guess=orange ✓
# Person C: Hair=indigo, Guess=indigo ✓
# Person D: Hair=orange, Guess=orange ✓
# Total correct: 3/4 (75%)

# %% [markdown]
# # Classical vs Quantum

# %%
import sys
import os

# Add parent directory to path so we can import our modules
sys.path.append(os.path.abspath('..'))

from experiments.compare_hair_color_solutions import main

# %%
main()
# Out:
# ================================================================================
# HAIR COLOR ENIGMA: CLASSICAL VS. QUANTUM COMPARISON
# ================================================================================
#
# Comparison parameters:
# - Number of people: 4
# - Classical trials: 10000
# - Quantum shots: 1024 per job × 10 jobs = 10240 total
# Running classical simulation with 4 people (10000 trials)...
#
# Running 10000 simulations for 4 people...
# Started at: 2025-03-26 19:18:58
# Completed at: 2025-03-26 19:18:58
# Total time: 0.030 seconds
# Running quantum simulation with 4 people (1024 shots x 10 jobs)...
#
# Running quantum simulation for 4 people...
# Parameters: 10 jobs with 1024 shots each
#
# ================================================================================
# COMPARISON OF CLASSICAL AND QUANTUM APPROACHES (4 people)
# ================================================================================
#
# Theoretical Analysis:
#   Maximum possible success rate (all correct): 12.5000%
#   This is the mathematical limit for any strategy with this problem.
#
# Average correct answers:
#   Classical: 2.9956 / 4 (74.89% accuracy)
#   Quantum:   3.0615 / 4 (76.54% accuracy)
#   Theoretical maximum: 3.1250 / 4 (78.12% accuracy)
#
# All correct rate (success rate):
#   Classical: 24.5400% (1.96x theoretical maximum)
#   Quantum:   6.1523% (0.49x theoretical maximum)
#   Theoretical maximum: 12.5000%
#   ✗ Quantum implementation is underperforming relative to theoretical maximum
#
# Per-person correct rates:
#   First person (theoretical ideal: 50%):
#     Classical: 49.57%
#     Quantum:   50.17%
#   Individual success rates:
#     Person | Classical (Expected) | Quantum (Measured)
#     --------------------------------------------------
#       A    |         50%         |      50.17%
#       B    |        100%         |      50.19%
#       C    |        100%         |      49.35%
#       D    |        100%         |      50.02%
#   Other people average success rate: 49.85% (Expected: 100%)
#   ⚠️ The quantum implementation's success rate for people 2-N is lower than expected
#      This suggests the quantum circuit may not be implementing the ideal strategy
#
# Distribution of correct answers:
#   Number Correct | Classical | Quantum  | Theoretical Maximum
#   ------------------------------------------------------------
#         0       |    0.00% |    6.07% |    0.00%
#         1       |    0.00% |   25.45% |    0.00%
#         2       |   24.98% |   37.31% |    0.00%
#         3       |   50.48% |   25.01% |   87.50%
#         4       |   24.54% |    6.15% |   12.50%
#
# Execution time:
#   Classical: 0.030 seconds
#   Quantum:   0.023 seconds
#
# Interpretation:
#   For 4 people:
#   - Classical solution achieves 298.9% higher success rate than the quantum
#   - People B, C, D have unexpectedly low success rates in the quantum implementation
#
#   Key takeaways:
#   - Both approaches demonstrate the same theoretical limit of correct guesses
#   - The optimal strategy has a 12.5000% chance of all 4 people guessing correctly
#   - When not all guesses are correct, the optimal strategy ensures only the first person is wrong
#   - The quantum implementation may need adjustment to fully match the optimal strategy
#
# Quantum Circuit Metrics:
#   depth: 15
#   width: 16
#   size: 25
#   count_ops:
#     cx: 12
#     measure: 8
#     h: 5
#     barrier: 5
#   num_qubits: 8
#   num_clbits: 8
#   num_ancillas: 0
#   num_parameters: 0
#   has_calibrations: False
#   has_layout: False
# Comparison complete. Plots saved as:
# - 'hair_color_comparison_4_people.png'
# - 'hair_color_efficiency_4_people.png'
# - 'hair_color_per_person_4_people.png'
